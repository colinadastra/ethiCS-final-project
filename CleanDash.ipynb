# %%
# CleanDash - A user friendly file to display our final project
# Produced by Colin Howard and Luke Moffit for CSCI 77800 -- EthiCS, Fall 2024

# Import Required Libraries
from IPython import get_ipython
from IPython.display import Markdown, display
import nbformat

# Load Dashboard Notebook
with open("Dashboard.ipynb", "r") as f:
    dashboard_nb = nbformat.read(f, as_version=4)

# Extract and display all cells
for i, cell in enumerate(dashboard_nb.cells):
    #print(f"Cell {i} is of type {cell.cell_type}")
    #try:
        if cell.cell_type == 'code':
            #print(f"Executing code cell {i}")
            get_ipython().run_cell(cell.source)
        else:
            
            try:
                #print(f"Markdown content: {cell.source}")
                #print(f"Type of Markdown: {type(Markdown)}")
                display(Markdown(cell.source))
            except Exception as e:
                print(f"Error displaying markdown cell {i}: {e}")
    #except Exception as e:
    #    print(f"Error processing cell {i}: {e}")
# Out:
# Welcome to the School Achievement Dashboard! Here, we will look at various factors to educate decision-makers on how best to invest to improve student learning outcomes.
#
# *Produced by Colin Howard and Luke Moffit for CSCI 77800 -- EthiCS, Fall 2024*
#
# # Part 1. Poverty and Achievement
#
# Start by running all of the cells in this notebook. Then use the dropdown below to choose whether to look at city-, state-, or national-level data.
# Does this first markdown run? No it does not. What if I move the level selector?
# ...
# # Part 2. Poverty and Funding
# FigureWidget({
#     'data': [{'name': 'ALABAMA',
#               'type': 'scatter',
#               'uid': '6eb2349a-6a2b-49f8-8736-8bc13d69629c',
#               'x': array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010,
#                           2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998,
# ...

# %%
#debugging space
# Import Required Libraries
from IPython import get_ipython
from IPython.display import Markdown, display
import nbformat

# Ensure that the correct Markdown class is being used
# print(f"Markdown class: {Markdown}")
# print(f"Markdown class type: {type(Markdown)}")

# Load Dashboard Notebook
#with open("CleanDashTester.ipynb", "r") as f:
with open("Dashboard.ipynb", "r") as f:
    dashboard_nb = nbformat.read(f, as_version=4)
    
# List to store cell types
# cell_types = []

# Extract and list all cell types from Dashboard.ipynb
# for i, cell in enumerate(dashboard_nb.cells):
#    cell_types.append(cell.cell_type)

# Print the list of cell types
# print("Cell types in the notebook:", cell_types)
        
# Display all of the markdown cells with formatting
for i, cell in enumerate(dashboard_nb.cells):
    if cell.cell_type == "markdown":
        #print(f"Type of Markdown: {type(Markdown)}")
        #if isinstance(cell.source, str):
        #        print("Markdown content is a string.")
        #else:
        #        print("Markdown content is not a string.")
        display(Markdown(cell.source))
        
# Display all cells, using getitem
# for i, cell in enumerate(dashboard_nb.cells):
#    display(cell)

for i, cell in enumerate(dashboard_nb.cells):
    #print(f"Cell {i} is of type {cell.cell_type}")
    #try:
        if cell.cell_type == 'code':
            #print(f"Executing code cell {i}")
            get_ipython().run_cell(cell.source)
        else:
            
            try:
                #print(f"Markdown content: {cell.source}")
                #print(f"Type of Markdown: {type(Markdown)}")
                display(Markdown(cell.source))
            except Exception as e:
                print(f"Error displaying markdown cell {i}: {e}")

# %%
#minimal example for debugging
from IPython import get_ipython
from IPython.display import Markdown, display
import nbformat

# Load Dashboard Notebook
with open("CleanDashTester.ipynb", "r") as f:
#with open("Dashboard.ipynb", "r") as f:
    dashboard_nb = nbformat.read(f, as_version=4)
    

# Function to display a specific markdown cell by index
# Function to display a specific markdown cell by index
def display_markdown_cell(index):
    cell = dashboard_nb.cells[index]
    if cell.cell_type == "markdown":
        try:
            # Destroy the old Markdown import
            #del Markdown
            # Re-import Markdown to ensure it's in the correct state
            from IPython.display import Markdown
            display(Markdown(cell.source))
        except Exception as e:
            print(f"Fudge! Error displaying markdown cell {index}: {e}")

# Function to execute a specific code cell by index
def execute_code_cell(index):
    cell = dashboard_nb.cells[index]
    if cell.cell_type == "code":
        try:
            get_ipython().run_cell(cell.source)
        except Exception as e:
            print(f"Error executing code cell {index}: {e}")

# Example usage:
# Display markdown cells
##display_markdown_cell(0)
display_markdown_cell(2)

# Execute code cells
#execute_code_cell(1)
#execute_code_cell(3)
# Why do Markdown cells stop working after the code executes! Is it the interactive widgets?
#display_markdown_cell(2)

# Continue with other cells as needed

#CleanDashTester.ipynb - a loop to call all cells in the notebook
execute_code_cell(0)
display_markdown_cell(1)
execute_code_cell(2)
display_markdown_cell(3)
